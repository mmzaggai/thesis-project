# %%
# STEP 7 — BERTopic for all data
# Input : merged_preprocessed_for_topics.csv
# Outputs: topics_per_doc.csv, topic_summary.csv
# FINAL run (MTS=30)

# Config & imports
import os, math
import pandas as pd
from tqdm.auto import tqdm
from pathlib import Path

from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
import hdbscan
from sentence_transformers import SentenceTransformer

# Files
INPUT = "merged_preprocessed_for_topics.csv"   # has clean_for_topics, dt, subreddit, id, kind, etc.
RUN_TAG = "mts30_fast"                         

TOPICS_PER_DOC_CSV = f"topics_per_doc_{RUN_TAG}.csv"
TOPIC_SUMMARY_CSV  = f"topic_summary_{RUN_TAG}.csv"

# Hyperparams
MIN_TOPIC_SIZE = 30           # MTS
TRAIN_MAX_DOCS = 100_000      # subset size for model fit
CAP_PER_WEEK   = 500          # stratify: max docs per week per subreddit/kind
BATCH_SIZE     = 2048         # transform batches
EMB_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2" 

# Speed knobs for BERTopic
# 1) Light embedding model
embedder = SentenceTransformer(EMB_MODEL_NAME)

# 2) Fast UMAP (lower n_components, mild neighbors)
umap_model = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.1,
    metric="cosine",
    random_state=42,
    low_memory=True,
)

# 3) HDBSCAN tuned for speed/stability
cluster_model = hdbscan.HDBSCAN(
    min_cluster_size=MIN_TOPIC_SIZE,
    min_samples=max(5, MIN_TOPIC_SIZE // 2),
    metric="euclidean",
    cluster_selection_method="eom",
    prediction_data=True,     # speeds up a lot
)

# 4) Vectorizer: cap vocab (min_df filters rares, max_features caps size)
vectorizer_model = CountVectorizer(
    ngram_range=(1, 2),
    min_df=10,             # drop very rare terms
    max_df=0.5,            # drop extremely frequent terms
    max_features=60_000,   # cap vocab
    stop_words="english",
)

topic_model = BERTopic(
    embedding_model=embedder,
    umap_model=umap_model,
    hdbscan_model=cluster_model,
    vectorizer_model=vectorizer_model,
    min_topic_size=MIN_TOPIC_SIZE,
    nr_topics="auto",                 # allow light merging of near-duplicate topics
    calculate_probabilities=False,    # speeds up
    low_memory=True,                  # reduces RAM
    verbose=True,
)

# Load data
df_full = pd.read_csv(INPUT, low_memory=False)
assert "clean_for_topics" in df_full.columns, "Missing 'clean_for_topics' column from preprocessing step."
assert "dt" in df_full.columns, "Missing 'dt' column."

# Keep only rows with usable text
df_full["clean_for_topics"] = df_full["clean_for_topics"].astype(str).str.strip()
df_full = df_full[df_full["clean_for_topics"].str.split().str.len() >= 3].copy()
df_full["dt"] = pd.to_datetime(df_full["dt"], errors="coerce", utc=True)

# Build stratified training subset (balanced in time & subreddit/kind)
df_full["week"] = df_full["dt"].dt.to_period("W-MON").astype(str)

group_cols = [c for c in ["subreddit","kind","week"] if c in df_full.columns]
if not group_cols:
    group_cols = ["week"]

def cap_group(g, cap=CAP_PER_WEEK):
    if len(g) <= cap:
        return g
    return g.sample(cap, random_state=42)

df_train = (df_full
            .groupby(group_cols, group_keys=False)
            .apply(cap_group, cap=CAP_PER_WEEK)
            .sample(min(TRAIN_MAX_DOCS, len(df_full)), random_state=42)
            .reset_index(drop=True))

print(f"[info] Training subset: {len(df_train):,} docs (of {len(df_full):,})")

# Fit on subset
train_texts = df_train["clean_for_topics"].tolist()
topics_train, _ = topic_model.fit_transform(train_texts)
print("[ok] Fit complete.")

# Build & save topic summary from the trained model
topic_info = topic_model.get_topic_info().rename(columns={"Count":"count","Name":"name","Topic":"topic"})
topic_info.to_csv(TOPIC_SUMMARY_CSV, index=False)
print(f"[ok] Wrote topic summary → {TOPIC_SUMMARY_CSV}")

# STransform the full dataset in batches (assign topics)
def batched(iterable, n):
    for i in range(0, len(iterable), n):
        yield i, iterable[i:i+n]

all_topics = []
all_probs  = []  # not used (probabilities disabled)
for i, batch in tqdm(batched(df_full["clean_for_topics"].tolist(), BATCH_SIZE),
                     total=math.ceil(len(df_full)/BATCH_SIZE), desc="Transform full"):
    bt, _ = topic_model.transform(batch)
    all_topics.extend(bt)

# Collect per-doc outputs
out = df_full[["id","subreddit","kind","dt","clean_for_topics"]].copy()
out["topic"] = all_topics
# map to human-readable names now (can also do later)
name_map = topic_info.set_index("topic")["name"].to_dict()
out["topic_name"] = out["topic"].map(name_map)

out.to_csv(TOPICS_PER_DOC_CSV, index=False)
print(f"[ok] Wrote per-doc topics → {TOPICS_PER_DOC_CSV}")

# Small quality check
print(out["topic"].value_counts().head(10).sort_index())
print("\nPreview:")
display(out.head(5))
# Out:
# 2025-10-19 19:10:08,199 - BERTopic - Embedding - Transforming documents to embeddings.
# [info] Training subset: 100,000 docs (of 447,012)
# Batches: 100%|██████████| 3125/3125 [28:03<00:00,  1.86it/s]
# 2025-10-19 19:38:17,096 - BERTopic - Embedding - Completed ✓
# 2025-10-19 19:38:17,097 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-10-19 23:41:36,473 - BERTopic - Dimensionality - Completed ✓
# 2025-10-19 23:41:36,481 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-10-20 07:39:42,401 - BERTopic - Cluster - Completed ✓
# 2025-10-20 07:39:42,403 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-10-20 07:39:55,081 - BERTopic - Representation - Completed ✓
# 2025-10-20 07:39:55,087 - BERTopic - Topic reduction - Reducing number of topics
# 2025-10-20 07:39:55,345 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-10-20 07:40:14,287 - BERTopic - Representation - Completed ✓
# 2025-10-20 07:40:14,305 - BERTopic - Topic reduction - Reduced number of topics from 303 to 116
# [ok] Fit complete.
# [ok] Wrote topic summary → topic_summary_mts30_fast.csv
# Batches: 100%|██████████| 64/64 [2:00:15<00:00, 112.74s/it]
# 2025-10-20 09:40:31,640 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:40:48,399 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:40:48,399 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:40:49,020 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:53<00:00,  1.19it/s]8, 7233.25s/it]
# 2025-10-20 09:41:42,795 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:41:45,257 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:41:45,257 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:41:45,873 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:55<00:00,  1.15it/s]0, 3011.85s/it]
# 2025-10-20 09:42:41,465 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:42:44,330 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:42:44,330 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:42:45,296 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [01:00<00:00,  1.06it/s], 1663.70s/it]
# 2025-10-20 09:43:45,824 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:43:48,584 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:43:48,584 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:43:49,467 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:55<00:00,  1.16it/s], 1032.23s/it]
# 2025-10-20 09:44:44,882 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:44:47,810 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:44:47,812 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:44:49,392 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:53<00:00,  1.19it/s], 681.60s/it]
# 2025-10-20 09:45:43,348 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:45:45,367 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:45:45,367 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:45:45,864 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:43<00:00,  1.47it/s], 469.06s/it]
# 2025-10-20 09:46:29,449 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:46:31,430 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:46:31,431 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:46:31,950 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:53<00:00,  1.20it/s], 330.78s/it]
# 2025-10-20 09:47:25,232 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:47:28,588 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:47:28,590 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:47:29,626 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:55<00:00,  1.15it/s], 243.84s/it]
# 2025-10-20 09:48:25,402 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:48:28,260 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:48:28,261 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:48:29,222 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:54<00:00,  1.17it/s], 186.24s/it]
# 2025-10-20 09:49:23,835 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:49:25,740 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:49:25,741 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:49:26,219 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:42<00:00,  1.52it/s], 146.34s/it]
# 2025-10-20 09:50:08,420 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:50:10,357 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:50:10,358 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:50:10,844 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.68it/s], 115.21s/it]
# 2025-10-20 09:50:48,950 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:50:50,909 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:50:50,910 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:50:51,379 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.72it/s], 92.49s/it]
# 2025-10-20 09:51:28,590 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:51:30,483 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:51:30,484 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:51:30,967 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.71it/s], 76.47s/it]
# 2025-10-20 09:52:08,461 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:52:10,351 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:52:10,352 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:52:10,818 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.65it/s], 65.41s/it]
# 2025-10-20 09:52:49,741 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:52:51,665 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:52:51,666 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:52:52,103 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.88it/s], 58.14s/it]
# 2025-10-20 09:53:26,173 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:53:28,142 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:53:28,143 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:53:28,615 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.77it/s], 51.63s/it]
# 2025-10-20 09:54:04,928 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:54:06,854 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:54:06,855 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:54:07,316 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.60it/s], 47.74s/it]
# 2025-10-20 09:54:47,445 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:54:49,345 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:54:49,346 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:54:49,819 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.57it/s], 46.17s/it]
# 2025-10-20 09:55:30,767 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:55:32,691 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:55:32,691 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:55:33,156 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.15it/s], 45.32s/it]
# 2025-10-20 09:56:03,030 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:56:05,087 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:56:05,087 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:56:05,577 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.80it/s], 41.45s/it]
# 2025-10-20 09:56:41,293 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:56:43,319 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:56:43,320 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:56:43,831 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.96it/s], 40.49s/it]
# 2025-10-20 09:57:16,639 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:57:18,621 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:57:18,622 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:57:19,130 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.18it/s], 38.93s/it]
# 2025-10-20 09:57:48,535 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:57:50,472 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:57:50,473 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:57:50,959 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.99it/s], 36.80s/it]
# 2025-10-20 09:58:23,207 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:58:25,382 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:58:25,383 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:58:25,950 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.07it/s], 36.26s/it]
# 2025-10-20 09:58:56,986 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:58:58,890 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:58:58,891 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:58:59,380 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.82it/s], 35.41s/it]
# 2025-10-20 09:59:34,571 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 09:59:36,543 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 09:59:36,544 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 09:59:37,029 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.09it/s], 36.08s/it]
# 2025-10-20 10:00:07,728 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:00:09,635 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:00:09,636 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:00:10,110 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.96it/s], 35.18s/it]
# 2025-10-20 10:00:42,872 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:00:44,796 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:00:44,797 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:00:45,282 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.14it/s], 35.18s/it]
# 2025-10-20 10:01:15,296 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:01:17,250 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:01:17,251 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:01:17,738 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:28<00:00,  2.23it/s], 34.36s/it]
# 2025-10-20 10:01:46,497 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:01:48,559 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:01:48,560 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:01:49,056 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:31<00:00,  2.01it/s], 33.45s/it]
# 2025-10-20 10:02:20,909 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:02:22,890 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:02:22,892 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:02:23,390 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:31<00:00,  2.03it/s], 33.71s/it]
# 2025-10-20 10:02:55,051 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:02:57,035 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:02:57,037 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:02:57,537 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.14it/s], 33.84s/it]
# 2025-10-20 10:03:27,496 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:03:29,447 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:03:29,447 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:03:29,935 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.16it/s], 33.41s/it]
# 2025-10-20 10:03:59,582 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:04:01,547 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:04:01,547 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:04:02,042 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.99it/s], 33.02s/it]
# 2025-10-20 10:04:34,259 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:04:36,218 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:04:36,219 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:04:36,711 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.13it/s], 33.51s/it]
# 2025-10-20 10:05:06,802 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:05:08,754 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:05:08,755 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:05:09,240 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.96it/s], 33.22s/it]
# 2025-10-20 10:05:42,042 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:05:43,961 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:05:43,962 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:05:44,446 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.91it/s], 33.81s/it]
# 2025-10-20 10:06:18,091 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:06:20,395 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:06:20,396 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:06:21,147 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.92it/s], 34.68s/it]
# 2025-10-20 10:06:54,639 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:06:56,584 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:06:56,585 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:06:57,071 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.99it/s], 35.05s/it]
# 2025-10-20 10:07:29,229 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:07:31,193 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:07:31,194 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:07:31,682 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:28<00:00,  2.21it/s], 34.92s/it]
# 2025-10-20 10:08:00,699 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:08:02,618 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:08:02,618 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:08:03,104 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.07it/s], 33.87s/it]
# 2025-10-20 10:08:34,073 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:08:36,010 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:08:36,011 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:08:36,509 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:27<00:00,  2.35it/s], 33.73s/it]
# 2025-10-20 10:09:03,768 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:09:05,744 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:09:05,745 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:09:06,241 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.71it/s], 32.53s/it]
# 2025-10-20 10:09:43,728 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:09:45,688 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:09:45,689 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:09:46,198 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.93it/s], 34.76s/it]
# 2025-10-20 10:10:19,404 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:10:21,416 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:10:21,417 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:10:21,907 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  2.00it/s], 35.04s/it]
# 2025-10-20 10:10:54,076 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:10:56,016 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:10:56,017 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:10:56,499 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.94it/s], 34.91s/it]
# 2025-10-20 10:11:29,616 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:11:31,485 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:11:31,486 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:11:31,945 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.87it/s], 35.07s/it]
# 2025-10-20 10:12:06,177 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:12:08,178 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:12:08,178 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:12:08,681 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.10it/s], 35.57s/it]
# 2025-10-20 10:12:39,162 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:12:41,072 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:12:41,073 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:12:41,557 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:31<00:00,  2.00it/s], 34.76s/it]
# 2025-10-20 10:13:13,610 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:13:15,493 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:13:15,494 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:13:15,970 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.91it/s], 34.66s/it]
# 2025-10-20 10:13:49,602 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:13:51,469 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:13:51,470 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:13:51,964 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.89it/s], 35.06s/it]
# 2025-10-20 10:14:25,893 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:14:27,841 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:14:27,841 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:14:28,318 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.93it/s], 35.45s/it]
# 2025-10-20 10:15:01,519 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:15:03,442 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:15:03,442 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:15:03,926 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.99it/s], 35.50s/it]
# 2025-10-20 10:15:36,106 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 10:15:37,995 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 10:15:37,996 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 10:15:38,453 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [1:03:16<00:00, 59.32s/it]35.20s/it]
# 2025-10-20 11:18:55,299 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:18:57,246 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:18:57,246 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:18:57,726 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.72it/s]5, 1164.42s/it]
# 2025-10-20 11:19:35,056 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:19:36,971 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:19:36,972 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:19:37,446 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.96it/s]3, 827.01s/it]
# 2025-10-20 11:20:10,264 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:20:12,204 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:20:12,205 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:20:12,695 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.98it/s]6, 589.48s/it]
# 2025-10-20 11:20:45,017 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:20:46,968 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:20:46,969 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:20:47,455 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.91it/s]3, 423.07s/it]
# 2025-10-20 11:21:21,041 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:21:23,255 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:21:23,256 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:21:23,826 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.92it/s]9, 307.06s/it]
# 2025-10-20 11:21:57,249 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:21:59,197 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:21:59,197 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:21:59,690 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:31<00:00,  2.03it/s], 225.70s/it]
# 2025-10-20 11:22:31,238 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:22:33,199 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:22:33,199 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:22:33,690 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.92it/s], 168.19s/it]
# 2025-10-20 11:23:07,053 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:23:08,971 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:23:08,972 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:23:09,457 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.59it/s], 128.46s/it]
# 2025-10-20 11:23:49,766 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:23:51,847 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:23:51,848 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:23:52,356 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.91it/s], 102.79s/it]
# 2025-10-20 11:24:26,050 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:24:28,577 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:24:28,578 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:24:29,083 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.59it/s], 82.97s/it]
# 2025-10-20 11:25:09,319 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:25:11,281 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:25:11,282 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:25:11,767 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.67it/s], 70.89s/it]
# 2025-10-20 11:25:50,215 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:25:52,124 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:25:52,125 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:25:52,609 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.68it/s], 61.87s/it]
# 2025-10-20 11:26:30,787 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:26:32,698 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:26:32,699 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:26:33,185 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.65it/s], 55.48s/it]
# 2025-10-20 11:27:12,031 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:27:13,979 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:27:13,979 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:27:14,468 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.09it/s], 51.22s/it]
# 2025-10-20 11:27:45,118 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:27:47,028 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:27:47,029 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:27:47,487 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.98it/s], 45.76s/it]
# 2025-10-20 11:28:19,951 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:28:22,014 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:28:22,016 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:28:22,497 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.80it/s], 42.54s/it]
# 2025-10-20 11:28:58,248 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:29:00,308 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:29:00,309 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:29:00,781 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.83it/s], 41.26s/it]
# 2025-10-20 11:29:35,842 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:29:37,802 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:29:37,804 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:29:38,272 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.74it/s], 40.13s/it]
# 2025-10-20 11:30:16,756 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:30:18,757 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:30:18,758 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:30:19,265 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:41<00:00,  1.56it/s], 40.39s/it]
# 2025-10-20 11:31:00,505 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:31:02,485 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:31:02,486 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:31:02,972 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.68it/s], 41.38s/it]
# 2025-10-20 11:31:41,188 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:31:43,130 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:31:43,131 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:31:43,606 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.61it/s], 41.16s/it]
# 2025-10-20 11:32:23,408 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:32:25,373 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:32:25,374 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:32:25,858 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.77it/s], 41.49s/it]
# 2025-10-20 11:33:02,076 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:33:04,089 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:33:04,090 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:33:04,576 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:32<00:00,  1.99it/s], 40.66s/it]
# 2025-10-20 11:33:36,885 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:33:38,825 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:33:38,826 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:33:39,308 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.88it/s], 38.88s/it]
# 2025-10-20 11:34:13,384 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:34:15,465 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:34:15,466 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:34:15,963 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.71it/s], 38.21s/it]
# 2025-10-20 11:34:53,433 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:34:55,462 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:34:55,463 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:34:55,939 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:41<00:00,  1.56it/s], 38.74s/it]
# 2025-10-20 11:35:37,121 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:35:39,013 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:35:39,014 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:35:39,469 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.77it/s], 40.18s/it]
# 2025-10-20 11:36:15,810 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:36:17,748 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:36:17,750 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:36:18,313 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.63it/s], 39.78s/it]
# 2025-10-20 11:36:57,799 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:36:59,770 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:36:59,771 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:37:00,260 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.76it/s], 40.43s/it]
# 2025-10-20 11:37:36,693 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:37:38,610 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:37:38,611 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:37:39,088 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.73it/s], 39.95s/it]
# 2025-10-20 11:38:16,231 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:38:18,213 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:38:18,214 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:38:18,705 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.76it/s], 39.85s/it]
# 2025-10-20 11:38:55,107 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:38:57,060 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:38:57,061 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:38:57,533 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.76it/s], 39.54s/it]
# 2025-10-20 11:39:34,035 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:39:36,019 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:39:36,020 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:39:36,519 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.60it/s], 39.38s/it]
# 2025-10-20 11:40:16,613 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:40:18,589 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:40:18,591 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:40:19,080 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.67it/s], 40.33s/it]
# 2025-10-20 11:40:57,535 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:40:59,517 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:40:59,518 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:40:59,998 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.83it/s], 40.51s/it]
# 2025-10-20 11:41:35,031 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:41:36,947 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:41:36,948 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:41:37,438 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.62it/s], 39.59s/it]
# 2025-10-20 11:42:17,110 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:42:19,056 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:42:19,057 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:42:19,528 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.71it/s], 40.34s/it]
# 2025-10-20 11:42:57,085 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:42:59,033 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:42:59,035 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:42:59,513 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:41<00:00,  1.53it/s], 40.23s/it]
# 2025-10-20 11:43:41,362 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:43:43,349 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:43:43,349 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:43:43,824 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.87it/s], 41.46s/it]
# 2025-10-20 11:44:18,168 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:44:20,120 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:44:20,121 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:44:20,654 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.69it/s], 40.07s/it]
# 2025-10-20 11:44:58,573 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:45:00,514 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:45:00,515 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:45:00,997 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.58it/s], 40.15s/it]
# 2025-10-20 11:45:41,720 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:45:43,685 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:45:43,686 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:45:44,138 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:42<00:00,  1.52it/s], 41.05s/it]
# 2025-10-20 11:46:26,317 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:46:28,315 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:46:28,316 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:46:28,793 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.79it/s], 42.13s/it]
# 2025-10-20 11:47:04,628 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:47:06,596 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:47:06,597 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:47:07,085 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.69it/s], 40.98s/it]
# 2025-10-20 11:47:45,164 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:47:47,091 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:47:47,093 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:47:47,580 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.78it/s], 40.83s/it]
# 2025-10-20 11:48:23,589 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 11:48:25,403 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 11:48:25,404 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 11:48:25,854 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [3:51:38<00:00, 217.17s/it]40.07s/it]
# 2025-10-20 15:40:04,681 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:40:06,844 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:40:06,845 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:40:07,347 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.57it/s]:02, 4198.49s/it]
# 2025-10-20 15:40:48,293 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:40:50,362 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:40:50,364 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:40:50,922 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:46<00:00,  1.39it/s]26, 2952.02s/it]
# 2025-10-20 15:41:37,213 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:41:39,455 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:41:39,457 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:41:40,034 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.69it/s]32, 2081.15s/it]
# 2025-10-20 15:42:18,018 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:42:19,834 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:42:19,835 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:42:20,301 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:35<00:00,  1.80it/s]21, 1468.88s/it]
# 2025-10-20 15:42:56,025 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:42:57,819 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:42:57,820 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:42:58,235 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.83it/s]14, 1039.60s/it]
# 2025-10-20 15:43:33,334 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 15:43:35,195 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 15:43:35,196 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 15:43:35,673 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [1:17:15<00:00, 72.43s/it], 738.95s/it]
# 2025-10-20 17:00:51,294 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:00:54,065 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:00:54,066 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:00:54,556 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:44<00:00,  1.44it/s]20, 1908.93s/it]
# 2025-10-20 17:01:39,191 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:01:41,232 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:01:41,232 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:01:41,686 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.62it/s]13, 1350.39s/it]
# 2025-10-20 17:02:21,292 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:02:23,101 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:02:23,101 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:02:23,491 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:36<00:00,  1.78it/s]00, 957.82s/it]
# 2025-10-20 17:02:59,603 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:03:01,482 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:03:01,485 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:03:01,988 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.59it/s]00, 682.02s/it]
# 2025-10-20 17:03:42,425 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:03:44,540 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:03:44,540 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:03:45,005 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.85it/s]34, 490.32s/it]
# 2025-10-20 17:04:19,763 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:04:21,527 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:04:21,527 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:04:21,926 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:42<00:00,  1.51it/s]49, 354.30s/it]
# 2025-10-20 17:05:04,446 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:05:10,508 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:05:10,510 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:05:12,236 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [01:53<00:00,  1.78s/it]8, 263.10s/it]
# 2025-10-20 17:07:06,686 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:07:11,236 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:07:11,238 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:07:12,498 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:49<00:00,  1.30it/s]6, 220.25s/it]
# 2025-10-20 17:08:01,819 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:08:04,035 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:08:04,036 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:08:04,549 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.56it/s]8, 169.79s/it]
# 2025-10-20 17:08:45,690 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:08:47,782 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:08:47,783 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:08:48,281 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:33<00:00,  1.89it/s]3, 131.97s/it]
# 2025-10-20 17:09:22,336 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:09:24,347 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:09:24,348 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:09:24,802 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.88it/s]0, 103.34s/it]
# 2025-10-20 17:09:58,953 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:10:00,943 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:10:00,944 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:10:01,415 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:42<00:00,  1.49it/s]5, 83.32s/it]
# 2025-10-20 17:10:44,526 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:10:46,561 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:10:46,563 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:10:47,026 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.59it/s]0, 72.01s/it]
# 2025-10-20 17:11:27,513 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 17:11:29,505 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 17:11:29,507 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 17:11:29,990 - BERTopic - Cluster - Completed ✓
# ...
# 2025-10-20 18:14:30,575 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:14:30,576 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:14:31,058 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.87it/s], 44.09s/it]
# 2025-10-20 18:15:05,307 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:15:07,269 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:15:07,271 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:15:07,761 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:39<00:00,  1.61it/s], 41.87s/it]
# 2025-10-20 18:15:47,570 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:15:49,488 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:15:49,494 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:15:49,990 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.59it/s], 41.98s/it]
# 2025-10-20 18:16:30,295 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:16:32,234 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:16:32,236 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:16:32,732 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:54<00:00,  1.17it/s], 42.21s/it]
# 2025-10-20 18:17:27,417 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:17:30,535 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:17:30,537 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:17:31,366 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:49<00:00,  1.30it/s], 47.14s/it]
# 2025-10-20 18:18:20,705 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:18:23,683 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:18:23,685 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:18:24,303 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:45<00:00,  1.40it/s], 48.88s/it]
# 2025-10-20 18:19:10,227 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:19:12,402 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:19:12,404 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:19:13,096 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:44<00:00,  1.43it/s], 48.85s/it]
# 2025-10-20 18:19:57,840 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:20:00,420 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:20:00,422 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:20:01,273 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:52<00:00,  1.23it/s], 48.65s/it]
# 2025-10-20 18:20:53,618 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:20:55,742 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:20:55,744 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:20:56,377 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s], 50.59s/it]
# 2025-10-20 18:21:41,546 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:21:43,805 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:21:43,807 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:21:44,407 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:38<00:00,  1.67it/s], 49.82s/it]
# 2025-10-20 18:22:22,835 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:22:24,998 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:22:24,999 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:22:25,519 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:43<00:00,  1.46it/s], 47.21s/it]
# 2025-10-20 18:23:09,606 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:23:11,607 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:23:11,609 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:23:12,116 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:40<00:00,  1.60it/s], 47.02s/it]
# 2025-10-20 18:23:52,301 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:23:54,272 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:23:54,274 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:23:54,760 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:37<00:00,  1.73it/s], 45.71s/it]
# 2025-10-20 18:24:31,950 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:24:33,917 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:24:33,918 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:24:34,404 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:34<00:00,  1.87it/s], 43.89s/it]
# 2025-10-20 18:25:08,824 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:25:10,669 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:25:10,670 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:25:11,090 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:26<00:00,  2.39it/s], 41.73s/it]
# 2025-10-20 18:25:37,924 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:25:39,764 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:25:39,765 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:25:40,193 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.74it/s], 37.94s/it]
# 2025-10-20 18:26:03,638 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:26:05,500 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:26:05,502 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:26:05,924 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:24<00:00,  2.61it/s], 34.28s/it]
# 2025-10-20 18:26:30,555 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:26:32,352 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:26:32,353 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:26:32,748 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.74it/s], 32.04s/it]
# 2025-10-20 18:26:56,185 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:26:57,967 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:26:57,968 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:26:58,387 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.82it/s], 30.12s/it]
# 2025-10-20 18:27:21,160 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:27:22,963 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:27:22,964 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:27:23,368 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.70it/s], 28.58s/it]
# 2025-10-20 18:27:47,193 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:27:48,989 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:27:48,990 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:27:49,393 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.81it/s], 27.81s/it]
# 2025-10-20 18:28:12,208 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:28:14,017 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:28:14,018 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:28:14,449 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.74it/s], 26.99s/it]
# 2025-10-20 18:28:37,856 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:28:39,610 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:28:39,611 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:28:40,014 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.81it/s], 26.56s/it]
# 2025-10-20 18:29:02,857 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:29:04,705 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:29:04,706 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:29:05,111 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.88it/s], 26.12s/it]
# 2025-10-20 18:29:27,431 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:29:29,260 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:29:29,261 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:29:29,676 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.86it/s], 25.65s/it]
# 2025-10-20 18:29:52,159 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:29:54,005 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:29:54,006 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:29:54,415 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.68it/s], 25.38s/it]
# 2025-10-20 18:30:18,354 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:30:20,208 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:30:20,209 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:30:20,701 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:29<00:00,  2.14it/s], 25.65s/it]
# 2025-10-20 18:30:50,740 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:30:52,582 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:30:52,583 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:30:53,018 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.68it/s], 27.65s/it]
# 2025-10-20 18:31:17,003 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:31:18,810 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:31:18,812 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:31:19,244 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.67it/s], 27.22s/it]
# 2025-10-20 18:31:43,287 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:31:45,096 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:31:45,098 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:31:45,501 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:21<00:00,  3.02it/s], 26.93s/it]
# 2025-10-20 18:32:06,770 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:32:08,570 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:32:08,572 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:32:08,974 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.71it/s], 25.90s/it]
# 2025-10-20 18:32:32,694 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:32:34,585 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:32:34,586 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:32:34,994 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:22<00:00,  2.89it/s], 25.93s/it]
# 2025-10-20 18:32:57,243 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:32:59,103 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:32:59,104 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:32:59,571 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:26<00:00,  2.42it/s], 25.53s/it]
# 2025-10-20 18:33:26,174 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:33:28,321 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:33:28,322 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:33:28,744 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:23<00:00,  2.69it/s], 26.62s/it]
# 2025-10-20 18:33:52,657 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:33:54,665 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:33:54,667 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:33:55,117 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:30<00:00,  2.09it/s], 26.55s/it]
# 2025-10-20 18:34:25,814 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:34:27,701 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:34:27,702 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:34:28,125 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 64/64 [00:27<00:00,  2.34it/s], 28.48s/it]
# 2025-10-20 18:34:55,553 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:34:57,459 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:34:57,461 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:34:57,869 - BERTopic - Cluster - Completed ✓
# Batches: 100%|██████████| 18/18 [00:12<00:00,  1.40it/s], 28.86s/it]
# 2025-10-20 18:35:10,955 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-10-20 18:35:11,696 - BERTopic - Dimensionality - Completed ✓
# 2025-10-20 18:35:11,697 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-10-20 18:35:11,864 - BERTopic - Cluster - Completed ✓
# Transform full: 100%|██████████| 219/219 [10:54:57<00:00, 179.44s/it]
# [ok] Wrote per-doc topics → topics_per_doc_mts30_fast.csv
# topic
# -1     290290
#  0     114522
#  1       3831
#  2       5133
#  3       4852
#  4        927
#  6       1380
#  8       1003
#  11      1353
#  16       922
# Name: count, dtype: int64
#
# Preview:
#        id        subreddit  kind                        dt  \
# 0  gf34wp  IsraelPalestine  post 2020-05-07 09:08:08+00:00
# 1  gnle2w  IsraelPalestine  post 2020-05-20 23:18:00+00:00
# 2  ho0fmu  IsraelPalestine  post 2020-07-09 09:58:12+00:00
# 3  hm3cjv  IsraelPalestine  post 2020-07-06 07:46:19+00:00
# 4  i3c9om  IsraelPalestine  post 2020-08-04 03:54:01+00:00
#
#                                     clean_for_topics  topic  \
# 0  israelis should be more critical of israel as ...     -1
# 1  can we stop blaming israel for kids hamas kill...      0
# 2  conceding some points to pro palestinians sinc...     -1
# 3  you don t need to pick sides the entire rhetor...     -1
# 4  as a left wing european i can t support palest...     -1
#
#                           topic_name
# 0  -1_israel_jews_palestinians_hamas
# 1   0_genocide_comments_israel_hamas
# 2  -1_israel_jews_palestinians_hamas
# 3  -1_israel_jews_palestinians_hamas
# 4  -1_israel_jews_palestinians_hamas
